# %%
import spatialgeometry as sg
from swift import Swift
import spatialmath as sm
import numpy as np

# %%
env = Swift()
env.launch(realtime=True, browser="windows-default")

mesh = sg.Mesh(filename=r'C:\Users\lozan\OneDrive\Desktop\arm-test\atmae-arm.stl', scale=[0.001, 0.001, 0.001])

# Rotate 90° around X to stand the arm upright
mesh.T = sm.SE3.Rx(np.pi / 2)

env.add(mesh)

env.hold()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       7 mesh.T = sm.SE3.Rx(np.pi / 2)
#       9 env.add(mesh)
# ---> 11 env.hold()
#
# File c:\Users\lozan\OneDrive\Desktop\arm-test\venv\Lib\site-packages\swift\Swift.py:466, in Swift.hold(self)
#     459 """
#     460 hold() keeps the browser tab open i.e. stops the browser tab from
#     461 closing once the main script has finished.
#     462
#     463 """
#     465 while True:
# --> 466     time.sleep(1)
#
# KeyboardInterrupt:
